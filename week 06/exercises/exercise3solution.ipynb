# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.4.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from faker) (2025.1)
# Downloading faker-37.4.2-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    -------------------------------- ------- 1.6/1.9 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import threading
import time
from faker import Faker
import os

# %%
faker = Faker()
file_lock = threading.Lock()
folder_name = 'output'
file_name = 'phrases.txt'
file_path = os.path.join(folder_name, file_name)

os.makedirs(folder_name, exist_ok=True)

# %%
def generate_phrase_and_save(thread_id):
    phrase = faker.sentence()
    print(f"Thread {thread_id} is generating phrase: {phrase}")
    time.sleep(2)
    file_lock.acquire()
    try:
        with open(file_path, "a") as file:
            log_entry = f"Thread {thread_id}: {phrase}\n"
            file.write(log_entry)
        print(f"Thread {thread_id} has saved the phrase to the file.")
    finally:
        file_lock.release()

# %%
thread_ids = [0, 1, 2, 3]
threads = []
for thread_id in thread_ids:
    thread = threading.Thread(target=generate_phrase_and_save, args=(thread_id,))
    threads.append(thread)
    thread.start()
for thread in threads:
    thread.join()
print("All phrases have been saved to the file.")
# Out:
# Thread 0 is generating phrase: Push both rather always picture focus.
# Thread 1 is generating phrase: Include address process eat seat quality power summer.
# Thread 2 is generating phrase: Where build they low.
# Thread 3 is generating phrase: Television be even majority.
# Thread 0 has saved the phrase to the file.
# Thread 1 has saved the phrase to the file.
# Thread 2 has saved the phrase to the file.
# Thread 3 has saved the phrase to the file.
# All phrases have been saved to the file.
